# %%
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torchvision import transforms, datasets

# %%
apply_transform = transforms.Compose([transforms.Resize(32), transforms.ToTensor()])
BatchSize = 256 # change according to system specs

trainset = datasets.MNIST(root='./MNIST', train=True, download=True, transform=apply_transform)
trainLoader = torch.utils.data.DataLoader(trainset, batch_size=BatchSize,
                                          shuffle=True, num_workers=4) # Creating dataloader

# Validation set with random rotations in the range [-90,90]
testset = datasets.MNIST(root='./MNIST', train=False, download=True, transform=apply_transform)
testLoader = torch.utils.data.DataLoader(testset, batch_size=BatchSize,
                                         shuffle=False, num_workers=4) # Creating dataloader

# %%
class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        self.conv1 = nn.Conv2d(1, 6, kernel_size=5)
        self.pool1 = nn.MaxPool2d(kernel_size=2,stride=2)
        self.conv2 = nn.Conv2d(6, 16, kernel_size=5)
        self.pool2 = nn.MaxPool2d(kernel_size=2,stride=2)        
        self.fc1 = nn.Linear(400, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = self.pool2(x)
        x = x.view(-1, 400)
        x = F.relu(self.fc1(x)) 
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return F.log_softmax(x,dim=1)

# %%
use_gpu = torch.cuda.is_available()
net = LeNet()
optimizer = optim.Adam(net.parameters(), lr =0.01)
print(net)
if use_gpu:
    print('GPU is avaialble!')
    net = net.cuda()
# Out:
# LeNet(
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss() 
learning_rate = 0.01
num_epochs = 200

train_loss = []
train_acc = []
for epoch in range(num_epochs):
    
    running_loss = 0.0 
    running_corr = 0
        
    for i,data in enumerate(trainLoader):
        inputs,labels = data
        if use_gpu:
            inputs, labels = inputs.cuda(),labels.cuda() 
        # Initializing model gradients to zero
        #net.zero_grad()
        optimizer.zero_grad()
        # Data feed-forward through the network
        outputs = net(inputs)
        # Predicted class is the one with maximum probability
        preds = torch.argmax(outputs,dim=1)
        # Finding the loss
        loss = criterion(outputs, labels)
        # Accumulating the loss for each batch
        running_loss += loss 
        # Accumulate number of correct predictions
        running_corr += torch.sum(preds==labels)    
        
    totalLoss = running_loss/(i+1)
    # Calculating gradients
    totalLoss.backward()
    # Updating the model parameters
    optimizer.step()
    #for f in net.parameters():
        #f.data.sub_(f.grad.data * learning_rate)
        
    epoch_loss = running_loss.item()/(i+1)   #Total loss for one epoch
    epoch_acc = running_corr.item()/60000
    
    
         
    train_loss.append(epoch_loss) #Saving the loss over epochs for plotting the graph
    train_acc.append(epoch_acc) #Saving the accuracy over epochs for plotting the graph
       
        
    print('Epoch {:.0f}/{:.0f} : Training loss: {:.4f} | Training Accuracy: {:.4f}'.format(epoch+1,num_epochs,epoch_loss,epoch_acc*100))
# Out:
# Epoch 1/200 : Training loss: 2.3039 | Training Accuracy: 10.4400
# Epoch 2/200 : Training loss: 2.2881 | Training Accuracy: 20.1850
# Epoch 3/200 : Training loss: 2.2295 | Training Accuracy: 13.7883
# Epoch 4/200 : Training loss: 2.0817 | Training Accuracy: 23.9800
# Epoch 5/200 : Training loss: 1.9002 | Training Accuracy: 52.2983
# Epoch 6/200 : Training loss: 1.6213 | Training Accuracy: 45.3067
# Epoch 7/200 : Training loss: 1.3568 | Training Accuracy: 59.1283
# Epoch 8/200 : Training loss: 0.9974 | Training Accuracy: 71.9867
# Epoch 9/200 : Training loss: 0.8504 | Training Accuracy: 71.3467
# Epoch 10/200 : Training loss: 0.8400 | Training Accuracy: 71.2200
# Epoch 11/200 : Training loss: 0.8238 | Training Accuracy: 74.5083
# Epoch 12/200 : Training loss: 0.8241 | Training Accuracy: 74.1550
# Epoch 13/200 : Training loss: 0.6691 | Training Accuracy: 78.9117
# Epoch 14/200 : Training loss: 0.6235 | Training Accuracy: 79.6683
# Epoch 15/200 : Training loss: 0.5617 | Training Accuracy: 83.7900
# Epoch 16/200 : Training loss: 0.5679 | Training Accuracy: 83.4883
# Epoch 17/200 : Training loss: 0.5254 | Training Accuracy: 85.2100
# Epoch 18/200 : Training loss: 0.4808 | Training Accuracy: 86.4017
# Epoch 19/200 : Training loss: 0.4480 | Training Accuracy: 86.4283
# Epoch 20/200 : Training loss: 0.4079 | Training Accuracy: 87.4783
# Epoch 21/200 : Training loss: 0.3774 | Training Accuracy: 88.6967
# Epoch 22/200 : Training loss: 0.3549 | Training Accuracy: 89.5917
# Epoch 23/200 : Training loss: 0.3326 | Training Accuracy: 90.2483
# Epoch 24/200 : Training loss: 0.3186 | Training Accuracy: 90.6050
# Epoch 25/200 : Training loss: 0.3029 | Training Accuracy: 91.1233
# Epoch 26/200 : Training loss: 0.2876 | Training Accuracy: 91.5833
# Epoch 27/200 : Training loss: 0.2736 | Training Accuracy: 92.0567
# Epoch 28/200 : Training loss: 0.2554 | Training Accuracy: 92.4600
# Epoch 29/200 : Training loss: 0.2405 | Training Accuracy: 92.8050
# Epoch 30/200 : Training loss: 0.2312 | Training Accuracy: 93.1100
# Epoch 31/200 : Training loss: 0.2222 | Training Accuracy: 93.4783
# Epoch 32/200 : Training loss: 0.2143 | Training Accuracy: 93.7467
# Epoch 33/200 : Training loss: 0.2027 | Training Accuracy: 94.0450
# Epoch 34/200 : Training loss: 0.1917 | Training Accuracy: 94.3000
# Epoch 35/200 : Training loss: 0.1837 | Training Accuracy: 94.4400
# Epoch 36/200 : Training loss: 0.1766 | Training Accuracy: 94.6483
# Epoch 37/200 : Training loss: 0.1677 | Training Accuracy: 94.9217
# Epoch 38/200 : Training loss: 0.1589 | Training Accuracy: 95.1417
# Epoch 39/200 : Training loss: 0.1519 | Training Accuracy: 95.3450
# Epoch 40/200 : Training loss: 0.1445 | Training Accuracy: 95.5817
# Epoch 41/200 : Training loss: 0.1378 | Training Accuracy: 95.7167
# Epoch 42/200 : Training loss: 0.1317 | Training Accuracy: 95.9033
# Epoch 43/200 : Training loss: 0.1258 | Training Accuracy: 96.0533
# Epoch 44/200 : Training loss: 0.1201 | Training Accuracy: 96.2367
# Epoch 45/200 : Training loss: 0.1147 | Training Accuracy: 96.4100
# Epoch 46/200 : Training loss: 0.1095 | Training Accuracy: 96.6033
# Epoch 47/200 : Training loss: 0.1050 | Training Accuracy: 96.7633
# Epoch 48/200 : Training loss: 0.1002 | Training Accuracy: 96.9167
# Epoch 49/200 : Training loss: 0.0961 | Training Accuracy: 97.0100
# Epoch 50/200 : Training loss: 0.0926 | Training Accuracy: 97.1567
# Epoch 51/200 : Training loss: 0.0888 | Training Accuracy: 97.3083
# Epoch 52/200 : Training loss: 0.0854 | Training Accuracy: 97.4400
# Epoch 53/200 : Training loss: 0.0826 | Training Accuracy: 97.5017
# Epoch 54/200 : Training loss: 0.0796 | Training Accuracy: 97.6183
# Epoch 55/200 : Training loss: 0.0771 | Training Accuracy: 97.6633
# Epoch 56/200 : Training loss: 0.0741 | Training Accuracy: 97.7550
# Epoch 57/200 : Training loss: 0.0715 | Training Accuracy: 97.8633
# Epoch 58/200 : Training loss: 0.0694 | Training Accuracy: 97.8850
# Epoch 59/200 : Training loss: 0.0672 | Training Accuracy: 97.9800
# Epoch 60/200 : Training loss: 0.0654 | Training Accuracy: 97.9983
# Epoch 61/200 : Training loss: 0.0638 | Training Accuracy: 98.1017
# Epoch 62/200 : Training loss: 0.0624 | Training Accuracy: 98.1333
# Epoch 63/200 : Training loss: 0.0608 | Training Accuracy: 98.1867
# Epoch 64/200 : Training loss: 0.0592 | Training Accuracy: 98.2183
# Epoch 65/200 : Training loss: 0.0578 | Training Accuracy: 98.2833
# Epoch 66/200 : Training loss: 0.0562 | Training Accuracy: 98.3217
# Epoch 67/200 : Training loss: 0.0548 | Training Accuracy: 98.3550
# Epoch 68/200 : Training loss: 0.0537 | Training Accuracy: 98.3967
# Epoch 69/200 : Training loss: 0.0526 | Training Accuracy: 98.4300
# Epoch 70/200 : Training loss: 0.0513 | Training Accuracy: 98.4767
# Epoch 71/200 : Training loss: 0.0502 | Training Accuracy: 98.4933
# Epoch 72/200 : Training loss: 0.0491 | Training Accuracy: 98.5333
# Epoch 73/200 : Training loss: 0.0481 | Training Accuracy: 98.5767
# Epoch 74/200 : Training loss: 0.0472 | Training Accuracy: 98.5833
# Epoch 75/200 : Training loss: 0.0463 | Training Accuracy: 98.6217
# Epoch 76/200 : Training loss: 0.0454 | Training Accuracy: 98.6600
# Epoch 77/200 : Training loss: 0.0443 | Training Accuracy: 98.7000
# Epoch 78/200 : Training loss: 0.0434 | Training Accuracy: 98.7417
# Epoch 79/200 : Training loss: 0.0426 | Training Accuracy: 98.7650
# Epoch 80/200 : Training loss: 0.0419 | Training Accuracy: 98.7600
# Epoch 81/200 : Training loss: 0.0413 | Training Accuracy: 98.8100
# Epoch 82/200 : Training loss: 0.0404 | Training Accuracy: 98.8350
# Epoch 83/200 : Training loss: 0.0395 | Training Accuracy: 98.8533
# Epoch 84/200 : Training loss: 0.0388 | Training Accuracy: 98.8717
# Epoch 85/200 : Training loss: 0.0382 | Training Accuracy: 98.8967
# Epoch 86/200 : Training loss: 0.0376 | Training Accuracy: 98.9017
# Epoch 87/200 : Training loss: 0.0370 | Training Accuracy: 98.9183
# Epoch 88/200 : Training loss: 0.0365 | Training Accuracy: 98.9500
# Epoch 89/200 : Training loss: 0.0358 | Training Accuracy: 98.9633
# Epoch 90/200 : Training loss: 0.0352 | Training Accuracy: 98.9750
# Epoch 91/200 : Training loss: 0.0344 | Training Accuracy: 99.0167
# Epoch 92/200 : Training loss: 0.0338 | Training Accuracy: 99.0300
# Epoch 93/200 : Training loss: 0.0333 | Training Accuracy: 99.0483
# Epoch 94/200 : Training loss: 0.0327 | Training Accuracy: 99.0783
# Epoch 95/200 : Training loss: 0.0322 | Training Accuracy: 99.0850
# Epoch 96/200 : Training loss: 0.0317 | Training Accuracy: 99.0967
# Epoch 97/200 : Training loss: 0.0313 | Training Accuracy: 99.1267
# Epoch 98/200 : Training loss: 0.0308 | Training Accuracy: 99.1250
# Epoch 99/200 : Training loss: 0.0304 | Training Accuracy: 99.1433
# Epoch 100/200 : Training loss: 0.0299 | Training Accuracy: 99.1400
# Epoch 101/200 : Training loss: 0.0295 | Training Accuracy: 99.1467
# Epoch 102/200 : Training loss: 0.0292 | Training Accuracy: 99.1417
# Epoch 103/200 : Training loss: 0.0287 | Training Accuracy: 99.1683
# Epoch 104/200 : Training loss: 0.0283 | Training Accuracy: 99.1783
# Epoch 105/200 : Training loss: 0.0276 | Training Accuracy: 99.2117
# Epoch 106/200 : Training loss: 0.0269 | Training Accuracy: 99.2300
# Epoch 107/200 : Training loss: 0.0263 | Training Accuracy: 99.2400
# Epoch 108/200 : Training loss: 0.0260 | Training Accuracy: 99.2417
# Epoch 109/200 : Training loss: 0.0257 | Training Accuracy: 99.2633
# Epoch 110/200 : Training loss: 0.0255 | Training Accuracy: 99.2700
# Epoch 111/200 : Training loss: 0.0253 | Training Accuracy: 99.2850
# Epoch 112/200 : Training loss: 0.0250 | Training Accuracy: 99.2883
# Epoch 113/200 : Training loss: 0.0244 | Training Accuracy: 99.3017
# Epoch 114/200 : Training loss: 0.0238 | Training Accuracy: 99.3167
# Epoch 115/200 : Training loss: 0.0232 | Training Accuracy: 99.3567
# Epoch 116/200 : Training loss: 0.0229 | Training Accuracy: 99.3500
# Epoch 117/200 : Training loss: 0.0224 | Training Accuracy: 99.3583
# Epoch 118/200 : Training loss: 0.0222 | Training Accuracy: 99.3783
# Epoch 119/200 : Training loss: 0.0220 | Training Accuracy: 99.3750
# Epoch 120/200 : Training loss: 0.0217 | Training Accuracy: 99.3783
# Epoch 121/200 : Training loss: 0.0213 | Training Accuracy: 99.3983
# Epoch 122/200 : Training loss: 0.0211 | Training Accuracy: 99.3950
# Epoch 123/200 : Training loss: 0.0209 | Training Accuracy: 99.4183
# Epoch 124/200 : Training loss: 0.0206 | Training Accuracy: 99.4083
# Epoch 125/200 : Training loss: 0.0201 | Training Accuracy: 99.4267
# Epoch 126/200 : Training loss: 0.0194 | Training Accuracy: 99.4533
# Epoch 127/200 : Training loss: 0.0189 | Training Accuracy: 99.4650
# Epoch 128/200 : Training loss: 0.0187 | Training Accuracy: 99.4750
# Epoch 129/200 : Training loss: 0.0186 | Training Accuracy: 99.4667
# Epoch 130/200 : Training loss: 0.0183 | Training Accuracy: 99.4933
# Epoch 131/200 : Training loss: 0.0181 | Training Accuracy: 99.4900
# Epoch 132/200 : Training loss: 0.0177 | Training Accuracy: 99.5117
# Epoch 133/200 : Training loss: 0.0174 | Training Accuracy: 99.5217
# Epoch 134/200 : Training loss: 0.0172 | Training Accuracy: 99.5183
# Epoch 135/200 : Training loss: 0.0168 | Training Accuracy: 99.5483
# Epoch 136/200 : Training loss: 0.0164 | Training Accuracy: 99.5500
# Epoch 137/200 : Training loss: 0.0159 | Training Accuracy: 99.5783
# Epoch 138/200 : Training loss: 0.0156 | Training Accuracy: 99.5833
# Epoch 139/200 : Training loss: 0.0153 | Training Accuracy: 99.5900
# Epoch 140/200 : Training loss: 0.0152 | Training Accuracy: 99.5917
# Epoch 141/200 : Training loss: 0.0149 | Training Accuracy: 99.6017
# Epoch 142/200 : Training loss: 0.0146 | Training Accuracy: 99.6167
# Epoch 143/200 : Training loss: 0.0143 | Training Accuracy: 99.6317
# Epoch 144/200 : Training loss: 0.0141 | Training Accuracy: 99.6367
# Epoch 145/200 : Training loss: 0.0140 | Training Accuracy: 99.6350
# Epoch 146/200 : Training loss: 0.0141 | Training Accuracy: 99.6100
# Epoch 147/200 : Training loss: 0.0145 | Training Accuracy: 99.6200
# Epoch 148/200 : Training loss: 0.0154 | Training Accuracy: 99.5317
# Epoch 149/200 : Training loss: 0.0166 | Training Accuracy: 99.4917
# Epoch 150/200 : Training loss: 0.0197 | Training Accuracy: 99.3217
# Epoch 151/200 : Training loss: 0.0223 | Training Accuracy: 99.2383
# Epoch 152/200 : Training loss: 0.0265 | Training Accuracy: 99.0600
# Epoch 153/200 : Training loss: 0.0209 | Training Accuracy: 99.3150
# Epoch 154/200 : Training loss: 0.0144 | Training Accuracy: 99.5967
# Epoch 155/200 : Training loss: 0.0180 | Training Accuracy: 99.4217
# Epoch 156/200 : Training loss: 0.0137 | Training Accuracy: 99.6150
# Epoch 157/200 : Training loss: 0.0164 | Training Accuracy: 99.4850
# Epoch 158/200 : Training loss: 0.0129 | Training Accuracy: 99.6550
# Epoch 159/200 : Training loss: 0.0152 | Training Accuracy: 99.5250
# Epoch 160/200 : Training loss: 0.0123 | Training Accuracy: 99.6800
# Epoch 161/200 : Training loss: 0.0140 | Training Accuracy: 99.5883
# Epoch 162/200 : Training loss: 0.0120 | Training Accuracy: 99.7067
# Epoch 163/200 : Training loss: 0.0127 | Training Accuracy: 99.6583
# Epoch 164/200 : Training loss: 0.0118 | Training Accuracy: 99.6850
# Epoch 165/200 : Training loss: 0.0116 | Training Accuracy: 99.7133
# Epoch 166/200 : Training loss: 0.0113 | Training Accuracy: 99.7133
# Epoch 167/200 : Training loss: 0.0109 | Training Accuracy: 99.7300
# Epoch 168/200 : Training loss: 0.0108 | Training Accuracy: 99.7317
# Epoch 169/200 : Training loss: 0.0104 | Training Accuracy: 99.7400
# Epoch 170/200 : Training loss: 0.0103 | Training Accuracy: 99.7600
# Epoch 171/200 : Training loss: 0.0099 | Training Accuracy: 99.7800
# Epoch 172/200 : Training loss: 0.0099 | Training Accuracy: 99.7600
# Epoch 173/200 : Training loss: 0.0094 | Training Accuracy: 99.7817
# Epoch 174/200 : Training loss: 0.0094 | Training Accuracy: 99.8050
# Epoch 175/200 : Training loss: 0.0090 | Training Accuracy: 99.8133
# Epoch 176/200 : Training loss: 0.0089 | Training Accuracy: 99.7950
# Epoch 177/200 : Training loss: 0.0087 | Training Accuracy: 99.8150
# Epoch 178/200 : Training loss: 0.0085 | Training Accuracy: 99.8317
# Epoch 179/200 : Training loss: 0.0084 | Training Accuracy: 99.8283
# Epoch 180/200 : Training loss: 0.0081 | Training Accuracy: 99.8250
# Epoch 181/200 : Training loss: 0.0081 | Training Accuracy: 99.8317
# Epoch 182/200 : Training loss: 0.0077 | Training Accuracy: 99.8383
# Epoch 183/200 : Training loss: 0.0078 | Training Accuracy: 99.8517
# Epoch 184/200 : Training loss: 0.0074 | Training Accuracy: 99.8550
# Epoch 185/200 : Training loss: 0.0075 | Training Accuracy: 99.8500
# Epoch 186/200 : Training loss: 0.0071 | Training Accuracy: 99.8600
# Epoch 187/200 : Training loss: 0.0071 | Training Accuracy: 99.8667
# Epoch 188/200 : Training loss: 0.0069 | Training Accuracy: 99.8650
# Epoch 189/200 : Training loss: 0.0068 | Training Accuracy: 99.8650
# Epoch 190/200 : Training loss: 0.0066 | Training Accuracy: 99.8767
# Epoch 191/200 : Training loss: 0.0065 | Training Accuracy: 99.8800
# Epoch 192/200 : Training loss: 0.0064 | Training Accuracy: 99.8733
# Epoch 193/200 : Training loss: 0.0062 | Training Accuracy: 99.8917
# Epoch 194/200 : Training loss: 0.0061 | Training Accuracy: 99.8933
# Epoch 195/200 : Training loss: 0.0061 | Training Accuracy: 99.8917
# Epoch 196/200 : Training loss: 0.0059 | Training Accuracy: 99.8900
# Epoch 197/200 : Training loss: 0.0058 | Training Accuracy: 99.8983
# Epoch 198/200 : Training loss: 0.0057 | Training Accuracy: 99.8983
# Epoch 199/200 : Training loss: 0.0055 | Training Accuracy: 99.9067
# Epoch 200/200 : Training loss: 0.0055 | Training Accuracy: 99.9100

# %%
fig = plt.figure(figsize=[15,5]) 
plt.subplot(121)
plt.plot(range(num_epochs),train_loss,'r-',label='Loss') 
plt.legend(loc='upper right')
plt.xlabel('Epochs')
plt.ylabel('Training')
plt.subplot(122)
plt.plot(range(num_epochs),train_acc,'g-',label='Accuracy') 
plt.legend(loc='upper right')
plt.xlabel('Epochs')
plt.ylabel('Training')
# Out:
# Text(0, 0.5, 'Training')

# %%
correct_pred = 0
for data in testLoader:
    inputs,labels = data
    if use_gpu:
        inputs, labels = inputs.cuda(),labels.cuda()
    # Feedforward train data batch through model
    output = net(inputs) 
    # Predicted class is the one with maximum probability
    preds = torch.argmax(output,dim=1)
    correct_pred += torch.sum(preds==labels)

test_accuracy = correct_pred.item()/10000.0
print('Testing accuracy = ',test_accuracy*100)
# Out:
# Testing accuracy =  98.81
